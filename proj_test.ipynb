# %%
train_df = spark.read.format('csv').options(header='true', inferSchema='true').load('/FileStore/tables/train.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
building_metadata_df = spark.read.format('csv').options(header='true', inferSchema='true').load('/FileStore/tables/building_metadata.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
weather_train_df = spark.read.format('csv').options(header='true', inferSchema='true').load('/FileStore/tables/weather_train.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
####can skip this part
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(train_df.count())
print(train_df.na.drop().count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">20216100
# 20216100
# </div>

# %%
building_metadata_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[17]: 1449</div>

# %%
print(building_metadata_df.count())
print(building_metadata_df.na.drop().count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">1449
# 231
# </div>

# %%
weather_train_df.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: 139773</div>

# %%
print(weather_train_df.count())
print(weather_train_df.na.drop().count())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">139773
# 48780
# </div>

# %%
weather_train_df.groupBy("cloud_coverage").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+-----+
# cloud_coverage|count|
# +--------------+-----+
#           null|69173|
#            0.0|33871|
#            2.0|13585|
#            4.0|10241|
#            8.0| 3531|
#            6.0| 3521|
#            7.0| 3485|
#            1.0|  713|
#            3.0|  608|
#            5.0|  526|
#            9.0|  519|
# +--------------+-----+
#
# </div>

# %%
weather_train_df.groupBy("site_id").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-----+
# site_id|count|
# +-------+-----+
#       8| 8784|
#       0| 8784|
#       4| 8783|
#      13| 8783|
#       2| 8783|
#       6| 8782|
#      10| 8782|
#       9| 8780|
#       3| 8780|
#      14| 8777|
#       1| 8763|
#      12| 8755|
#       5| 8755|
#       7| 8614|
#      11| 8614|
#      15| 8454|
# +-------+-----+
#
# </div>

# %%
weather_train_df.groupBy("timestamp").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------------------+-----+
#           timestamp|count|
# +-------------------+-----+
# 2016-06-18 20:00:00|   16|
# 2016-12-10 15:00:00|   16|
# 2016-06-22 17:00:00|   16|
# 2016-01-14 18:00:00|   16|
# 2016-12-10 08:00:00|   16|
# 2016-06-26 02:00:00|   16|
# 2016-01-26 14:00:00|   16|
# 2016-07-13 03:00:00|   16|
# 2016-01-29 16:00:00|   16|
# 2016-07-25 13:00:00|   16|
# 2016-02-20 10:00:00|   16|
# 2016-07-29 11:00:00|   16|
# 2016-02-28 22:00:00|   16|
# 2016-08-04 12:00:00|   16|
# 2016-03-24 12:00:00|   16|
# 2016-08-21 19:00:00|   16|
# 2016-04-30 06:00:00|   16|
# 2016-08-26 16:00:00|   16|
# 2016-05-14 23:00:00|   16|
# 2016-08-30 04:00:00|   16|
# +-------------------+-----+
# only showing top 20 rows
#
# </div>

# %%
weather_train_df.groupBy("air_temperature").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------+-----+
# air_temperature|count|
# +---------------+-----+
#            15.0| 2722|
#            24.4| 2200|
#            20.0| 2191|
#            10.0| 2187|
#            25.0| 2185|
#            19.4| 2121|
#            23.9| 2115|
#            25.6| 2096|
#            17.2| 2095|
#            23.3| 2074|
#            18.3| 2067|
#            15.6| 2066|
#            20.6| 2043|
#            18.9| 2014|
#            14.4| 2010|
#            17.8| 2001|
#            22.8| 1989|
#            13.9| 1987|
#            21.7| 1971|
#            21.1| 1947|
# +---------------+-----+
# only showing top 20 rows
#
# </div>

# %%
weather_train_df.groupBy("dew_temperature").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+---------------+-----+
# dew_temperature|count|
# +---------------+-----+
#            10.0| 2759|
#            12.8| 2201|
#             5.0| 2196|
#            13.3| 2193|
#            11.7| 2188|
#            11.1| 2149|
#            22.8| 2144|
#            10.6| 2058|
#            12.2| 2056|
#             0.0| 2013|
#            22.2| 1986|
#            13.9| 1981|
#            23.3| 1967|
#            15.0| 1965|
#             8.9| 1902|
#             9.4| 1897|
#            21.7| 1851|
#            17.8| 1798|
#            16.1| 1796|
#            14.4| 1764|
# +---------------+-----+
# only showing top 20 rows
#
# </div>

# %%
weather_train_df.groupBy("precip_depth_1_hr").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-----+
# precip_depth_1_hr|count|
# +-----------------+-----+
#               0.0|77910|
#              null|50289|
#              -1.0| 5780|
#               3.0| 1469|
#               5.0|  720|
#               2.0|  517|
#               8.0|  447|
#              10.0|  369|
#              13.0|  264|
#              15.0|  194|
#              18.0|  167|
#              20.0|  127|
#               7.0|  103|
#               6.0|   90|
#              23.0|   80|
#              25.0|   75|
#              33.0|   73|
#              28.0|   70|
#              30.0|   68|
#               4.0|   68|
# +-----------------+-----+
# only showing top 20 rows
#
# </div>

# %%
weather_train_df.groupBy("sea_level_pressure").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+-----+
# sea_level_pressure|count|
# +------------------+-----+
#               null|10618|
#             1015.2|  851|
#             1017.7|  827|
#             1016.4|  799|
#             1016.3|  799|
#             1019.2|  798|
#             1018.2|  798|
#             1016.7|  795|
#             1016.2|  795|
#             1016.1|  791|
#             1015.4|  786|
#             1018.6|  785|
#             1016.9|  781|
#             1014.9|  781|
#             1015.8|  781|
#             1014.8|  780|
#             1016.5|  778|
#             1015.9|  778|
#             1018.4|  775|
#             1016.0|  775|
# +------------------+-----+
# only showing top 20 rows
#
# </div>

# %%
weather_train_df.groupBy("wind_direction").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+-----+
# wind_direction|count|
# +--------------+-----+
#            0.0|13154|
#           null| 6268|
#          270.0| 4950|
#          300.0| 4688|
#          280.0| 4660|
#          290.0| 4651|
#          170.0| 4627|
#          260.0| 4394|
#          310.0| 4009|
#          180.0| 3903|
#          190.0| 3755|
#           70.0| 3745|
#          160.0| 3744|
#          210.0| 3714|
#          200.0| 3671|
#          320.0| 3660|
#          330.0| 3362|
#          250.0| 3356|
#           60.0| 3312|
#          360.0| 3301|
# +--------------+-----+
# only showing top 20 rows
#
# </div>

# %%
weather_train_df.groupBy("wind_speed").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+
# wind_speed|count|
# +----------+-----+
#        2.1|14381|
#        2.6|14055|
#        0.0|13542|
#        1.5|13097|
#        3.1|12965|
#        3.6|11883|
#        4.1| 9980|
#        4.6| 8270|
#        5.1| 6639|
#        5.7| 5416|
#        6.2| 4459|
#        6.7| 3522|
#        7.2| 2775|
#        1.0| 2059|
#        7.7| 1980|
#        8.2| 1497|
#        4.0| 1413|
#        5.0| 1358|
#        6.0| 1152|
#        3.0| 1133|
# +----------+-----+
# only showing top 20 rows
#
# </div>

# %%
######skip above, run below
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
from pyspark.sql.functions import avg, col, when
from pyspark.sql.window import Window
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
w = Window().partitionBy('site_id')

#Replace negative values of 'qty' with Null, as we don't want to consider them while averaging.
#weather_train_df = weather_train_df.withColumn('qty',when(col('qty')<0,None).otherwise(col('qty')))
weather_train_df = weather_train_df.withColumn('cloud_coverage',when(col('cloud_coverage').isNull(),avg(col('cloud_coverage')).over(w)).otherwise(col('cloud_coverage')))
weather_train_df.show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-------+-------------------+---------------+--------------+---------------+-----------------+------------------+--------------+----------+
# site_id|          timestamp|air_temperature|cloud_coverage|dew_temperature|precip_depth_1_hr|sea_level_pressure|wind_direction|wind_speed|
# +-------+-------------------+---------------+--------------+---------------+-----------------+------------------+--------------+----------+
#      12|2016-01-01 00:00:00|            1.9|           4.0|           -1.2|             null|            1016.2|         200.0|       5.0|
#      12|2016-01-01 01:00:00|            1.6|           4.0|           -1.5|             null|            1016.3|         190.0|       3.0|
#      12|2016-01-01 02:00:00|            0.7|           4.0|           -1.8|             null|            1016.5|         170.0|       3.0|
#      12|2016-01-01 03:00:00|            0.8|           4.0|           -2.1|             null|            1016.4|         170.0|       4.0|
#      12|2016-01-01 04:00:00|            2.9|           4.0|           -1.6|             null|            1016.2|         130.0|       3.0|
#      12|2016-01-01 05:00:00|            3.0|           4.0|           -1.1|             null|            1015.7|         160.0|       4.0|
#      12|2016-01-01 06:00:00|            3.6|           4.0|           -0.6|             null|            1014.7|         150.0|       5.0|
#      12|2016-01-01 07:00:00|            3.9|           6.0|            0.3|             null|            1014.2|         150.0|       4.0|
#      12|2016-01-01 08:00:00|            3.9|           6.0|            0.7|             null|            1013.4|         120.0|       3.0|
#      12|2016-01-01 09:00:00|            5.7|           7.0|            2.9|             null|            1012.1|         140.0|       4.0|
#      12|2016-01-01 10:00:00|            7.6|           8.0|            3.9|             null|            1011.4|         140.0|      11.0|
#      12|2016-01-01 11:00:00|            7.6|           8.0|            3.8|             null|            1010.0|         140.0|      12.0|
#      12|2016-01-01 12:00:00|            7.9|           8.0|            4.3|             null|            1008.6|         140.0|      14.0|
#      12|2016-01-01 13:00:00|            7.0|           8.0|            5.5|             null|            1006.6|         130.0|      13.0|
#      12|2016-01-01 14:00:00|            7.2|           8.0|            5.5|             null|            1004.3|         130.0|      12.0|
#      12|2016-01-01 15:00:00|            7.5|           8.0|            5.8|             null|            1002.7|         130.0|      14.0|
#      12|2016-01-01 16:00:00|            7.8|           8.0|            6.4|             null|            1001.7|         120.0|      13.0|
#      12|2016-01-01 17:00:00|            8.1|           8.0|            6.5|             null|            1000.7|         120.0|      13.0|
#      12|2016-01-01 18:00:00|            8.2|           8.0|            7.0|             null|             999.8|         120.0|      13.0|
#      12|2016-01-01 19:00:00|            8.2|           8.0|            6.9|             null|             998.9|         120.0|      13.0|
# +-------+-------------------+---------------+--------------+---------------+-----------------+------------------+--------------+----------+
# only showing top 20 rows
#
# </div>

# %%
import pyspark.sql.functions as func
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
weather_train_df = weather_train_df.withColumn("cloud_coverage", func.round(weather_train_df["cloud_coverage"]).cast('integer'))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
weather_train_df.groupBy("cloud_coverage").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+-----+
# cloud_coverage|count|
# +--------------+-----+
#              0|49413|
#              2|20169|
#           null|17228|
#              1|14873|
#              4|13883|
#              3|12566|
#              6| 3580|
#              8| 3531|
#              7| 3485|
#              5|  526|
#              9|  519|
# +--------------+-----+
#
# </div>

# %%
w = Window().partitionBy('site_id')

#Replace negative values of 'qty' with Null, as we don't want to consider them while averaging.
#weather_train_df = weather_train_df.withColumn('qty',when(col('qty')<0,None).otherwise(col('qty')))
weather_train_df = weather_train_df.withColumn('wind_direction',when(col('wind_direction').isNull(),avg(col('wind_direction')).over(w)).otherwise(col('wind_direction')))
weather_train_df = weather_train_df.withColumn("wind_direction", func.round(weather_train_df["wind_direction"]).cast('integer'))
weather_train_df.groupBy("wind_direction").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+--------------+-----+
# wind_direction|count|
# +--------------+-----+
#              0|13154|
#            270| 4950|
#            300| 4688|
#            280| 4660|
#            290| 4651|
#            170| 4627|
#            180| 4437|
#            260| 4394|
#            310| 4009|
#            200| 3966|
#            190| 3755|
#             70| 3745|
#            160| 3744|
#            210| 3714|
#            320| 3660|
#            330| 3362|
#            250| 3356|
#             60| 3312|
#            360| 3301|
#            350| 3276|
# +--------------+-----+
# only showing top 20 rows
#
# </div>

# %%
weather_train_df = weather_train_df.withColumn('sea_level_pressure',when(col('sea_level_pressure').isNull(),avg(col('sea_level_pressure')).over(w)).otherwise(col('sea_level_pressure')))
weather_train_df.groupBy("sea_level_pressure").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+------------------+-----+
# sea_level_pressure|count|
# +------------------+-----+
#               null| 8755|
#             1015.2|  851|
#             1017.7|  827|
#             1016.3|  799|
#             1016.4|  799|
#             1018.2|  798|
#             1019.2|  798|
#             1016.2|  795|
#             1016.7|  795|
#             1016.1|  791|
#             1015.4|  786|
#             1018.6|  785|
#             1014.9|  781|
#             1015.8|  781|
#             1016.9|  781|
#             1014.8|  780|
#             1015.9|  778|
#             1016.5|  778|
#             1016.0|  775|
#             1018.4|  775|
# +------------------+-----+
# only showing top 20 rows
#
# </div>

# %%
weather_train_df = weather_train_df.withColumn('precip_depth_1_hr',when(col('precip_depth_1_hr').isNull(),avg(col('precip_depth_1_hr')).over(w)).otherwise(col('precip_depth_1_hr')))
weather_train_df = weather_train_df.withColumn("precip_depth_1_hr", func.round(weather_train_df["precip_depth_1_hr"]).cast('integer'))
weather_train_df.groupBy("precip_depth_1_hr").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------------+-----+
# precip_depth_1_hr|count|
# +-----------------+-----+
#                 0|79320|
#              null|26273|
#                11|15804|
#                 3| 8220|
#                -1| 5780|
#                 5|  720|
#                 2|  517|
#                 8|  447|
#                10|  369|
#                13|  264|
#                15|  194|
#                18|  167|
#                20|  127|
#                 7|  103|
#                 6|   90|
#                 1|   89|
#                23|   80|
#                25|   75|
#                33|   73|
#                28|   70|
# +-----------------+-----+
# only showing top 20 rows
#
# </div>

# %%
weather_train_df=weather_train_df.na.drop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
w = Window().partitionBy('primary_use')
building_metadata_df = building_metadata_df.withColumn('year_built',when(col('year_built').isNull(),avg(col('year_built')).over(w)).otherwise(col('year_built')))
building_metadata_df = building_metadata_df.withColumn("year_built", func.round(building_metadata_df["year_built"]).cast('integer'))
building_metadata_df.groupBy("year_built").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+----------+-----+
# year_built|count|
# +----------+-----+
#       1973|  259|
#       1963|  230|
#       1964|  120|
#       1971|  116|
#       1976|   56|
#       1982|   38|
#       1966|   23|
#       1968|   18|
#       1919|   17|
#       1999|   16|
#       2004|   14|
#       1958|   13|
#       2006|   13|
#       1975|   13|
#       1960|   13|
#       2007|   13|
#       2001|   12|
#       1970|   12|
#       2014|   12|
#       2010|   12|
# +----------+-----+
# only showing top 20 rows
#
# </div>

# %%
building_metadata_df = building_metadata_df.withColumn('floor_count',when(col('floor_count').isNull(),avg(col('floor_count')).over(w)).otherwise(col('floor_count')))
building_metadata_df = building_metadata_df.withColumn("floor_count", func.round(building_metadata_df["floor_count"]).cast('integer'))
building_metadata_df.groupBy("floor_count").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----+
# floor_count|count|
# +-----------+-----+
#           5|  405|
#           2|  331|
#           4|  276|
#           1|  154|
#           6|  154|
#           3|   52|
#           8|   19|
#        null|   18|
#           7|   14|
#           9|    8|
#          11|    5|
#          10|    4|
#          12|    2|
#          13|    2|
#          26|    1|
#          19|    1|
#          16|    1|
#          21|    1|
#          14|    1|
# +-----------+-----+
#
# </div>

# %%
building_metadata_df=building_metadata_df.na.drop()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
building_metadata_df = building_metadata_df.withColumn("primary_use", when(col("primary_use")=="Education", 1)
                                   .when(col("primary_use")=="Office", 2)
                                   .when(col("primary_use")=="Entertainment/public assembly", 3)
                                   .when(col("primary_use")=="Public services", 4)
                                   .when(col("primary_use")=="Lodging/residential", 5)
                                   .when(col("primary_use")=="Other", 6)
                                   .when(col("primary_use")=="Healthcare", 7)
                                   .when(col("primary_use")=="Parking", 8)
                                   .when(col("primary_use")=="Warehouse/storage", 9)
                                   .when(col("primary_use")=="Manufacturing/industrial", 10)
                                   .when(col("primary_use")=="Retail", 11)
                                   .when(col("primary_use")=="Services", 12)
                                   .when(col("primary_use")=="Technology/science", 13)
                                   .when(col("primary_use")=="Food sales and service", 14)
                                   .when(col("primary_use")=="Utility", 15)
                                   .when(col("primary_use")=="Religious worship", 16))
building_metadata_df.groupBy("primary_use").count().orderBy("count", ascending = False).show()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">+-----------+-----+
# primary_use|count|
# +-----------+-----+
#           1|  549|
#           2|  279|
#           3|  184|
#           4|  156|
#           5|  147|
#           6|   25|
#           7|   23|
#           8|   22|
#           9|   13|
#          10|   12|
#          11|   11|
#          13|    6|
#          15|    4|
# +-----------+-----+
#
# </div>

# %%
train_df = train_df.withColumn("meter_reading", when(col("meter")==0, col("meter_reading")*0.293))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
#####data processing ends here
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
meta_train_df =  building_metadata_df.join(train_df, (building_metadata_df['building_id'] == train_df['building_id']))
cond = [weather_train_df.site_id == meta_train_df.site_id, weather_train_df.timestamp == meta_train_df.timestamp]
trainDF =  weather_train_df.join(meta_train_df, cond)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
datasetDF = trainDF.drop("timestamp", "site_id", "building_id")
datasetDF = datasetDF.na.fill(0)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# ***** vectorizer MODEL ****
from pyspark.ml.feature import VectorAssembler

vectorizer = VectorAssembler()
vectorizer.setInputCols(["air_temperature", "cloud_coverage", "dew_temperature", "precip_depth_1_hr", "sea_level_pressure", 
                         "wind_direction", "wind_speed", "square_feet", "year_built", "floor_count", "meter"])
vectorizer.setOutputCol("features")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: VectorAssembler_07929a5c3b6a</div>

# %%
split15DF, split85DF = datasetDF.randomSplit([15., 85.], seed=190)

# Let's cache these datasets for performance
testSetDF = split15DF#.cache()
trainingSetDF = split85DF#.cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# ***** LINEAR REGRESSION MODEL ****

from pyspark.ml.regression import LinearRegression
from pyspark.ml.regression import LinearRegressionModel
from pyspark.ml import Pipeline

# Let's initialize our linear regression learner
lr = LinearRegression()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Now we set the parameters for the method
lr.setPredictionCol("predicted_meter_reading")\
  .setLabelCol("meter_reading")\
  .setMaxIter(100)\
  .setRegParam(0.15)


# We will use the new spark.ml pipeline API. If you have worked with scikit-learn this will be very familiar.
lrPipeline = Pipeline()

lrPipeline.setStages([vectorizer, lr])

# Let's first train on the entire dataset to see what we get
lrModel = lrPipeline.fit(trainingSetDF)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# The intercept is as follows:
intercept = lrModel.stages[1].intercept

# The coefficents (i.e., weights) are as follows:
weights = lrModel.stages[1].coefficients

# Create a list of the column names (without PE)
featuresNoLabel = [col for col in datasetDF.columns if col != "meter_reading"]

# Merge the weights and labels
coefficents = zip(weights, featuresNoLabel)

# Now let's sort the coefficients from greatest absolute weight most to the least absolute weight

equation = "y = {intercept}".format(intercept=intercept)
variables = []
for x in coefficents:
    weight = abs(x[0])
    name = x[1]
    symbol = "+" if (x[0] > 0) else "-"
    equation += (" {} ({} * {})".format(symbol, weight, name))

# Finally here is our equation
print("Linear Regression Equation: " + equation)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Linear Regression Equation: y = -499.7204147564002 - (0.057011336671138634 * air_temperature) + (0.5998525073930909 * cloud_coverage) + (0.2226976238592621 * dew_temperature) + (0.0004314695417977229 * precip_depth_1_hr) + (0.12956917876554735 * sea_level_pressure) + (0.006098025952851695 * wind_direction) + (0.2536656606356518 * wind_speed) + (0.00024150388062039405 * primary_use) + (0.18717029897506698 * square_feet) + (3.830463629917446 * year_built) - (25.79262006682498 * floor_count)
# </div>

# %%
resultsDF = lrModel.transform(testSetDF)#.select("AT", "V", "AP", "RH", "PE", "Prediction_PE")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# t = resultsDF.groupBy().agg({'predicted_meter_reading': "mean"})
from pyspark.sql.functions import *
# predictionCol = "predicted_meter_reading"
# labelCol = "meter_reading"
# dataset = resultsDF
# dataset = dataset.withColumn('result_'+predictionCol, log(col(predictionCol)+1))
# dataset = dataset.withColumn('result_'+labelCol, log(col(labelCol)+1))
# dataset = dataset.withColumn('result', (col('result_'+predictionCol) - col('result_'+labelCol)))
# result = dataset.agg(avg(col("result")))
# result = result.collect()[0]["avg(result)"]
# print(result)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Now let's compute an evaluation metric for our test dataset
from pyspark.ml.evaluation import Evaluator, RegressionEvaluator
from math import sqrt
from statistics import mean

class RMSLEEvaluator(Evaluator):

    def __init__(self, predictionCol="prediction", labelCol="label"):
        self.predictionCol = predictionCol
        self.labelCol = labelCol

    def _evaluate(self, dataset):
        """
        Returns a random number. 
        Implement here the true metric
        """
        new_dataset = dataset.withColumn('result_'+self.predictionCol, log(col(self.predictionCol)+1))
        new_dataset = new_dataset.withColumn('result_'+self.labelCol, log(col(self.labelCol)+1))
        new_dataset = new_dataset.withColumn('result', (col('result_'+self.predictionCol) - col('result_'+self.labelCol))**2)
        
        result = new_dataset.agg(avg(col("result")))
        result = result.collect()[0]["avg(result)"]
        return sqrt(result)
      
    def isLargerBetter(self):
        return True
# Create an RMSE evaluator using the label and predicted columns
regEval = RMSLEEvaluator(predictionCol="predicted_meter_reading", labelCol="meter_reading")

# Run the evaluator on the DataFrame
rmse = regEval.evaluate(resultsDF)

print("Root Mean Squared Error: %.2f" % rmse)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Root Mean Squared Error: 2.06
# </div>
